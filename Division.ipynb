# %%
72/2
# Out:
# 36.0

# %%
Division = 72/2

# %%
a= input ("Enter your first number")
# Out:
# Enter your first number72

# %%
type(a)
# Out:
# str

# %%
a=int(a)

# %%
type(a)
# Out:
# int

# %%
b= input ("Enter your second number")
# Out:
# Enter your second number2

# %%
type(b)
# Out:
# str

# %%
b=int(b)

# %%
type (b)
# Out:
# int

# %%
Sum1=a/b

# %%
print("Your Division is",Sum1)
# Out:
# Your Division is 36.0
