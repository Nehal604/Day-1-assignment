# %%
40*50
# Out:
# 2000

# %%
Multiplication =40*50

# %%
a= input ( "Enter your first number")
# Out:
# Enter your first number40

# %%
type(a)
# Out:
# str

# %%
a= int(a)

# %%
type(a)
# Out:
# int

# %%
b= input (" Enter your second number")
# Out:
#  Enter your second number50

# %%
type(b)
# Out:
# str

# %%
b= int(b)

# %%
type(b)
# Out:
# int

# %%
Sum1 = a * b

# %%
print ("Your multiplication is",Sum1)
# Out:
# Your multiplication is 2000
